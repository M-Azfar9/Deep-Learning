# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("diabetes.csv")

# %%
data.corr(numeric_only=True)['Outcome']
# Out:
# Pregnancies                 0.221898
# Glucose                     0.466581
# BloodPressure               0.065068
# SkinThickness               0.074752
# Insulin                     0.130548
# BMI                         0.292695
# DiabetesPedigreeFunction    0.173844
# Age                         0.238356
# Outcome                     1.000000
# Name: Outcome, dtype: float64

# %% [markdown]
# ____
# #### ***Here `BloodPressure` and `SkinThickness` are not so much matter for output but we keep it our dataset, bcz we are doing hyperparemeter tunning***
# ____
# <table border="1" cellspacing="0" cellpadding="5">
#   <tr>
#     <th>Feature</th>
#     <th>Value</th>
#   </tr>
#   <tr>
#     <td>Pregnancies</td>
#     <td>0.221898</td>
#   </tr>
#   <tr>
#     <td>Glucose</td>
#     <td>0.466581</td>
#   </tr>
#   <tr>
#     <td>BloodPressure</td>
#     <td>0.065068</td>
#   </tr>
#   <tr>
#     <td>SkinThickness</td>
#     <td>0.074752</td>
#   </tr>
#   <tr>
#     <td>Insulin</td>
#     <td>0.130548</td>
#   </tr>
#   <tr>
#     <td>BMI</td>
#     <td>0.292695</td>
#   </tr>
#   <tr>
#     <td>DiabetesPedigreeFunction</td>
#     <td>0.173844</td>
#   </tr>
#   <tr>
#     <td>Age</td>
#     <td>0.238356</td>
#   </tr>
#   <tr>
#     <td>Outcome</td>
#     <td>1.000000</td>
#   </tr>
# </table>

# %%
x = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# %%
# scaling
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_x = scaler.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(scaled_x, y, test_size=0.2, random_state=42)

# %%
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import Sequential

# %%
model = Sequential()
model.add(
    Dense(32, input_dim=8, activation='relu')
)
model.add(
    Dense(1, activation='sigmoid')
)
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, batch_size=32, verbose=1, epochs=100, validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6319 - loss: 0.6494 - val_accuracy: 0.7338 - val_loss: 0.5855
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6938 - loss: 0.6007 - val_accuracy: 0.7922 - val_loss: 0.5508
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7117 - loss: 0.5654 - val_accuracy: 0.7727 - val_loss: 0.5259
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7362 - loss: 0.5400 - val_accuracy: 0.7662 - val_loss: 0.5099
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7476 - loss: 0.5210 - val_accuracy: 0.7792 - val_loss: 0.4985
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7573 - loss: 0.5063 - val_accuracy: 0.7922 - val_loss: 0.4906
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7638 - loss: 0.4954 - val_accuracy: 0.7987 - val_loss: 0.4866
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7704 - loss: 0.4871 - val_accuracy: 0.7987 - val_loss: 0.4843
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7736 - loss: 0.4802 - val_accuracy: 0.7987 - val_loss: 0.4823
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7638 - loss: 0.4749 - val_accuracy: 0.7922 - val_loss: 0.4816
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7671 - loss: 0.4706 - val_accuracy: 0.7857 - val_loss: 0.4810
# Epoch 12/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7671 - loss: 0.4670 - val_accuracy: 0.7857 - val_loss: 0.4818
# Epoch 13/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7736 - loss: 0.4638 - val_accuracy: 0.7857 - val_loss: 0.4831
# Epoch 14/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7801 - loss: 0.4613 - val_accuracy: 0.7857 - val_loss: 0.4827
# Epoch 15/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7801 - loss: 0.4589 - val_accuracy: 0.7857 - val_loss: 0.4837
# Epoch 16/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7769 - loss: 0.4563 - val_accuracy: 0.7792 - val_loss: 0.4835
# Epoch 17/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7752 - loss: 0.4547 - val_accuracy: 0.7857 - val_loss: 0.4846
# Epoch 18/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7785 - loss: 0.4527 - val_accuracy: 0.7792 - val_loss: 0.4861
# Epoch 19/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.
# Epoch 66/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7964 - loss: 0.4121 - val_accuracy: 0.7727 - val_loss: 0.5308
# Epoch 67/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7964 - loss: 0.4114 - val_accuracy: 0.7727 - val_loss: 0.5308
# Epoch 68/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7964 - loss: 0.4112 - val_accuracy: 0.7662 - val_loss: 0.5306
# Epoch 69/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7980 - loss: 0.4109 - val_accuracy: 0.7727 - val_loss: 0.5309
# Epoch 70/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7980 - loss: 0.4102 - val_accuracy: 0.7662 - val_loss: 0.5342
# Epoch 71/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7948 - loss: 0.4099 - val_accuracy: 0.7727 - val_loss: 0.5350
# Epoch 72/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7964 - loss: 0.4091 - val_accuracy: 0.7727 - val_loss: 0.5348
# Epoch 73/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7980 - loss: 0.4088 - val_accuracy: 0.7727 - val_loss: 0.5334
# Epoch 74/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7980 - loss: 0.4090 - val_accuracy: 0.7662 - val_loss: 0.5357
# Epoch 75/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7997 - loss: 0.4080 - val_accuracy: 0.7662 - val_loss: 0.5328
# Epoch 76/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8013 - loss: 0.4077 - val_accuracy: 0.7597 - val_loss: 0.5339
# Epoch 77/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8013 - loss: 0.4067 - val_accuracy: 0.7597 - val_loss: 0.5358
# Epoch 78/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8013 - loss: 0.4066 - val_accuracy: 0.7597 - val_loss: 0.5364
# Epoch 79/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8029 - loss: 0.4058 - val_accuracy: 0.7597 - val_loss: 0.5384
# Epoch 80/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8029 - loss: 0.4051 - val_accuracy: 0.7662 - val_loss: 0.5424
# Epoch 81/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8046 - loss: 0.4054 - val_accuracy: 0.7532 - val_loss: 0.5432
# Epoch 82/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8046 - loss: 0.4049 - val_accuracy: 0.7597 - val_loss: 0.5419
# Epoch 83/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8046 - loss: 0.4042 - val_accuracy: 0.7532 - val_loss: 0.5433
# Epoch 84/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8013 - loss: 0.4040 - val_accuracy: 0.7597 - val_loss: 0.5431
# Epoch 85/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8046 - loss: 0.4031 - val_accuracy: 0.7532 - val_loss: 0.5435
# Epoch 86/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8029 - loss: 0.4033 - val_accuracy: 0.7532 - val_loss: 0.5431
# Epoch 87/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8029 - loss: 0.4027 - val_accuracy: 0.7532 - val_loss: 0.5432
# Epoch 88/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8078 - loss: 0.4025 - val_accuracy: 0.7468 - val_loss: 0.5438
# Epoch 89/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8078 - loss: 0.4019 - val_accuracy: 0.7532 - val_loss: 0.5448
# Epoch 90/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8143 - loss: 0.4014 - val_accuracy: 0.7532 - val_loss: 0.5449
# Epoch 91/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8111 - loss: 0.4014 - val_accuracy: 0.7468 - val_loss: 0.5441
# Epoch 92/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8127 - loss: 0.4011 - val_accuracy: 0.7468 - val_loss: 0.5445
# Epoch 93/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8094 - loss: 0.4003 - val_accuracy: 0.7532 - val_loss: 0.5484
# Epoch 94/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8094 - loss: 0.3997 - val_accuracy: 0.7468 - val_loss: 0.5479
# Epoch 95/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8111 - loss: 0.3996 - val_accuracy: 0.7468 - val_loss: 0.5488
# Epoch 96/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8094 - loss: 0.3993 - val_accuracy: 0.7468 - val_loss: 0.5492
# Epoch 97/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8111 - loss: 0.3986 - val_accuracy: 0.7403 - val_loss: 0.5516
# Epoch 98/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8078 - loss: 0.3981 - val_accuracy: 0.7403 - val_loss: 0.5512
# Epoch 99/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8143 - loss: 0.3981 - val_accuracy: 0.7403 - val_loss: 0.5525
# Epoch 100/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8094 - loss: 0.3973 - val_accuracy: 0.7468 - val_loss: 0.5521

# %% [markdown]
# <div>
#   <h2>🌱 What is Keras Tuner?</h2>
#
#   <p><strong>Keras Tuner</strong> is a tool for automatic hyperparameter tuning in deep learning.</p>
#
#   <p>When you build a neural network, you have to make choices like:</p>
#
#   <ul>
#     <li>How many layers to use?</li>
#     <li>How many neurons per layer?</li>
#     <li>Which activation function?</li>
#     <li>What learning rate?</li>
#     <li>Which optimizer?</li>
#   </ul>
#
#   <p>These choices are called <strong>hyperparameters</strong>. They are not learned by the model — you set them before training.</p>
# </div>

# %%
import keras_tuner as kt

# %%
# def build_model(hp):
#     model = Sequential([
#         Dense(32, activation='relu', input_dim=8),
#         Dense(1, activation='sigmoid')
#     ])

#     optimizer = hp.Choice('optimizer', values=['adam', 'sgd', 'rmsprop', 'adadelta'])
#     model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
#     return model

# %%
# # creating tuner object
# tuner = kt.RandomSearch(build_model,
#                         objective='val_accuracy',
#                         max_trials=5
#                         )

# %%
# tuner.search(x_train, y_train, epochs=5, validation_data=(x_test, y_test))

# %%
# tuner.get_best_hyperparameters()[0].values

# %%
# tuner.results_summary()

# %%
# # Now you can get the best model as well
# model = tuner.get_best_models(num_models=1)[0]

# %%
# model.summary()

# %%
# model.fit(x_train, y_train, batch_size=32, epochs=100, initial_epoch=6, validation_data=(x_test, y_test))

# %%
def build_model(hp):
    neurons = hp.Choice('units', [8, 32, 64, 128])
    # neurons = hp.Int('units', min_value=8, max_value=128, step=8)
    model = Sequential([
        Dense(neurons, input_dim=8, activation='relu'),
        Dense(1, activation='sigmoid'),
    ])
    model.compile(optimizer='adam', metrics=['accuracy'], loss='binary_crossentropy')
    return model
# def build_model(hp):
#   model = Sequential()
#   model.add(Dense(
#       hp.Choice('units', [8, 16, 32]),
#       activation='relu'))
#   model.add(Dense(1, activation='sigmoid'))
#   model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#   return model

# %%
tune = kt.RandomSearch(
    build_model, 
    objective='val_accuracy',
    max_trials=5
)

# %%
tune.search(x_train, y_train, epochs=5, validation_data=(x_test, y_test))
# Out:
# Trial 4 Complete [00h 00m 02s]
# val_accuracy: 0.7532467246055603
#
# Best val_accuracy So Far: 0.7792207598686218
# Total elapsed time: 00h 00m 08s

# %%
tune.results_summary()
# Out:
# Results summary
# Results in .\untitled_project
# Showing 10 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 2 summary
# Hyperparameters:
# units: 32
# Score: 0.7792207598686218
#
# Trial 3 summary
# Hyperparameters:
# units: 128
# Score: 0.7532467246055603
#
# Trial 1 summary
# Hyperparameters:
# units: 64
# Score: 0.7337662577629089
#
# Trial 0 summary
# Hyperparameters:
# units: 8
# Score: 0.6168830990791321

# %%
tune.get_best_hyperparameters()[0].values
# Out:
# {'units': 32}

# %%
# Get all trials from the tuner
trials = tune.oracle.trials

# Convert to a DataFrame
results = []
for trial_id, trial in trials.items():
    results.append({
        "trial_id": trial_id,
        "hyperparameters": trial.hyperparameters.values,
        "score": trial.score
    })

df = pd.DataFrame(results)

# %%
df
# Out:
#   trial_id hyperparameters     score
# 0        0    {'units': 8}  0.616883
# 1        1   {'units': 64}  0.733766
# 2        2   {'units': 32}  0.779221
# 3        3  {'units': 128}  0.753247

# %% [markdown]
# Number of Hidden Layers

# %%
def build_model(hp):
    model = Sequential()
    model.add(Dense(8, input_dim=8, activation='relu'))

    # for checking number of hidden layers
    for i in range(hp.Int('num_layers', min_value=1, max_value=10)):
        model.add(Dense(8, activation='relu'))

    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
tuner = kt.RandomSearch(
    build_model, 
    objective='val_accuracy',
    max_trials=5,
    directory='tuners',
    project_name='num_layers'
)
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
tuner.search(x_train, y_train, epochs=5, validation_data=(x_test, y_test))
# Out:
# Trial 5 Complete [00h 00m 04s]
# val_accuracy: 0.6428571343421936
#
# Best val_accuracy So Far: 0.701298713684082
# Total elapsed time: 00h 00m 17s

# %%
tuner.get_best_hyperparameters()[0].values
# Out:
# {'num_layers': 9}

# %%
best_model = tuner.get_best_models(num_models=1)[0]
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 46 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
best_model.fit(x_train, y_train, epochs=200, initial_epoch=6, validation_data=(x_test, y_test))
# Out:
# Epoch 7/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8485 - loss: 0.3697 - val_accuracy: 0.7273 - val_loss: 0.5652
# Epoch 8/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8567 - loss: 0.3684 - val_accuracy: 0.7403 - val_loss: 0.5675
# Epoch 9/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8534 - loss: 0.3675 - val_accuracy: 0.7273 - val_loss: 0.5636
# Epoch 10/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8518 - loss: 0.3697 - val_accuracy: 0.7338 - val_loss: 0.5674
# Epoch 11/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8518 - loss: 0.3696 - val_accuracy: 0.7143 - val_loss: 0.5850
# Epoch 12/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8404 - loss: 0.3758 - val_accuracy: 0.7208 - val_loss: 0.5603
# Epoch 13/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8534 - loss: 0.3707 - val_accuracy: 0.7338 - val_loss: 0.5678
# Epoch 14/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8453 - loss: 0.3832 - val_accuracy: 0.7403 - val_loss: 0.5627
# Epoch 15/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8436 - loss: 0.3748 - val_accuracy: 0.7273 - val_loss: 0.5644
# Epoch 16/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8550 - loss: 0.3682 - val_accuracy: 0.7403 - val_loss: 0.5550
# Epoch 17/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8567 - loss: 0.3678 - val_accuracy: 0.7403 - val_loss: 0.5574
# Epoch 18/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8664 - loss: 0.3630 - val_accuracy: 0.7273 - val_loss: 0.5747
# Epoch 19/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8599 - loss: 0.3617 - val_accuracy: 0.7273 - val_loss: 0.5683
# Epoch 20/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8518 - loss: 0.3670 - val_accuracy: 0.7338 - val_loss: 0.5750
# Epoch 21/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8469 - loss: 0.3782 - val_accuracy: 0.7273 - val_loss: 0.5754
# Epoch 22/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8550 - loss: 0.3634 - val_accuracy: 0.7338 - val_loss: 0.5583
# Epoch 23/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8599 - loss: 0.3581 - val_accuracy: 0.7208 - val_loss: 0.5786
# Epoch 24/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8632 - loss: 0.3613 - val_accuracy: 0.7273 - val_loss: 0.5735
# Epoch 25/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8583 - loss: 0.3609 - val_accuracy: 0.7273 - val_loss: 0.5823
# Epoch 26/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8599 - loss: 0.3578 - val_accuracy: 0.7208 - val_loss: 0.5889
# Epoch 27/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8648 - loss: 0.3581 - val_accuracy: 0.7338 - val_loss: 0.5689
# Epoch 28/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8632 - loss: 0.3607 - val_accuracy: 0.7273 - val_loss: 0.5860
# Epoch 29/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8599 - loss: 0.3572 - val_accuracy: 0.7143 - val_loss: 0.5979
# Epoch 30/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8567 - loss: 0.3595 - val_accuracy: 0.7273 - val_loss: 0.5903
# Epoch 31/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8616 - loss: 0.3608 - val_accuracy: 0.7338 - val_loss: 0.5789
# Epoch 32/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8469 - loss: 0.3624 - val_accuracy: 0.6948 - val_loss: 0.6050
# Epoch 33/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8550 - loss: 0.3656 - val_accuracy: 0.7208 - val_loss: 0.5953
# Epoch 34/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8730 - loss: 0.3510 - val_accuracy: 0.7143 - val_loss: 0.5800
# Epoch 35/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8599 - loss: 0.3585 - val_accuracy: 0.7273 - val_loss: 0.5924
# Epoch 36/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8697 - loss: 0.3456 - val_accuracy: 0.7208 - val_loss: 0.5921
# Epoch 37/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8811 - loss: 0.3438 - val_accuracy: 0.7273 - val_loss: 0.5898
# Epoch 38/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8567 - loss: 0.3518 - val_accuracy: 0.7208 - val_loss: 0.5952
# Epoch 39/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8730 - loss: 0.3467 - val_accuracy: 0.7273 - val_loss: 0.5952
# Epoch 40/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8567 - loss: 0.3520 - val_accuracy: 0.7403 - val_loss: 0.5975
# Epoch 41/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8632 - loss: 0.3534 - val_accuracy: 0.7208 - val_loss: 0.5923
# Epoch 42/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8681 - loss: 0.3466 - val_accuracy: 0.7208 - val_loss: 0.6015
# Epoch 43/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8534 - loss: 0.3652 - val_accuracy: 0.7143 - val_loss: 0.5966
# Epoch 44/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8697 - loss: 0.
# Epoch 178/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8518 - loss: 0.3300 - val_accuracy: 0.7532 - val_loss: 0.5815
# Epoch 179/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8567 - loss: 0.3238 - val_accuracy: 0.7468 - val_loss: 0.5785
# Epoch 180/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8550 - loss: 0.3258 - val_accuracy: 0.7403 - val_loss: 0.5940
# Epoch 181/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8632 - loss: 0.3219 - val_accuracy: 0.7208 - val_loss: 0.6595
# Epoch 182/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8681 - loss: 0.3138 - val_accuracy: 0.7208 - val_loss: 0.6777
# Epoch 183/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8762 - loss: 0.2974 - val_accuracy: 0.7338 - val_loss: 0.6690
# Epoch 184/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8779 - loss: 0.2916 - val_accuracy: 0.7273 - val_loss: 0.6952
# Epoch 185/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8844 - loss: 0.2889 - val_accuracy: 0.7403 - val_loss: 0.6867
# Epoch 186/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8827 - loss: 0.2870 - val_accuracy: 0.7143 - val_loss: 0.7587
# Epoch 187/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8811 - loss: 0.2901 - val_accuracy: 0.7273 - val_loss: 0.7107
# Epoch 188/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8811 - loss: 0.2878 - val_accuracy: 0.7338 - val_loss: 0.7191
# Epoch 189/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8811 - loss: 0.2953 - val_accuracy: 0.7208 - val_loss: 0.7180
# Epoch 190/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8795 - loss: 0.2855 - val_accuracy: 0.7143 - val_loss: 0.7414
# Epoch 191/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8795 - loss: 0.2814 - val_accuracy: 0.7338 - val_loss: 0.7043
# Epoch 192/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8827 - loss: 0.2839 - val_accuracy: 0.7273 - val_loss: 0.7036
# Epoch 193/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8664 - loss: 0.3157 - val_accuracy: 0.7273 - val_loss: 0.6819
# Epoch 194/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8730 - loss: 0.3013 - val_accuracy: 0.7208 - val_loss: 0.7319
# Epoch 195/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7866 - loss: 0.4388 - val_accuracy: 0.7468 - val_loss: 0.5359
# Epoch 196/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7508 - loss: 0.4592 - val_accuracy: 0.7078 - val_loss: 0.5343
# Epoch 197/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7818 - loss: 0.4155 - val_accuracy: 0.7078 - val_loss: 0.5225
# Epoch 198/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7932 - loss: 0.3936 - val_accuracy: 0.7273 - val_loss: 0.5160
# Epoch 199/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7997 - loss: 0.3843 - val_accuracy: 0.7273 - val_loss: 0.5245
# Epoch 200/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7997 - loss: 0.3788 - val_accuracy: 0.7208 - val_loss: 0.5229

# %% [markdown]
# For all types of tunning

# %%
def build_model(hp):
    model = Sequential()
    
    # 1. How many hidden layers to use?
    for i in range(hp.Int('num_layers', min_value=1, max_value=4)):
        # 2. How many neurons per layer?
        model.add(Dense(
            units=hp.Int(f'units_{i}', min_value=16, max_value=128, step=16),
            activation=hp.Choice('activation', values=['relu', 'tanh', 'sigmoid'])
        ))
        # dropouts
        model.add(Dropout(rate=hp.Float(f'dropout_{i}', min_value=0.0, max_value=0.5, step=0.1)))
    
    # Output layer (binary classification case)
    model.add(Dense(1, activation='sigmoid'))
    
    # 3. What learning rate? + 4. Which optimizer?
    optimizer_name = hp.Choice('optimizer', ['adam', 'sgd', 'rmsprop', 'adadelta'])
    
    model.compile(optimizer=optimizer_name, 
                  loss='binary_crossentropy', 
                  metrics=['accuracy'])
    return model

# %%
tuner = kt.RandomSearch(
    build_model, 
    objective='val_accuracy',
    max_trials=5,
    directory='tuners',
    project_name='all_params_final'
)

# %%
tuner.search(x_train, y_train, epochs=5, validation_data=(x_test, y_test))
# Out:
# Trial 5 Complete [00h 00m 03s]
# val_accuracy: 0.6428571343421936
#
# Best val_accuracy So Far: 0.7727272510528564
# Total elapsed time: 00h 00m 14s

# %%
tuner.get_best_hyperparameters()[0].values
# Out:
# {'num_layers': 1,
#  'units_0': 48,
#  'activation': 'relu',
#  'dropout_0': 0.0,
#  'optimizer': 'adam',
#  'units_1': 64,
#  'dropout_1': 0.4,
#  'units_2': 32,
#  'dropout_2': 0.30000000000000004}
